# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
clicked_data = pd.read_csv("advertising.csv")

# %%
clicked_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
clicked_data.tail()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                             Ad Topic Line           City  Male  \
# 995         Fundamental modular algorithm      Duffystad     1
# 996       Grass-roots cohesive monitoring    New Darlene     1
# 997          Expanded intangible solution  South Jessica     1
# 998  Proactive bandwidth-monitored policy    West Steven     0
# 999       Virtual 5thgeneration emulation    Ronniemouth     0
#
#                     Country            Timestamp  Clicked on Ad
# 995                 Lebanon  2016-02-11 21:49:00              1
# ...

# %%
clicked_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
clicked_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
# Count unique values for columns 4, 5, and 7
unique_values_4 = clicked_data['Ad Topic Line'].nunique()
unique_values_5 = clicked_data['City'].nunique()
unique_values_7 = clicked_data['Country'].nunique()

# Print the unique value counts
print('Unique values in Ad Topic Line:', unique_values_4)
print('Unique values in City:', unique_values_5)
print('Unique values in Country:', unique_values_7)
# Out:
# Unique values in Ad Topic Line: 1000
# Unique values in City: 969
# Unique values in Country: 237

# %%
# Define the transformation function
def convert_timestamp_to_time_slot(timestamp):
    hour = pd.to_datetime(timestamp).hour
    if hour >= 6 and hour < 12:
        return 'Morning'
    elif hour >= 12 and hour < 18:
        return 'Day'
    elif hour >= 18 and hour < 24:
        return 'Evening'
    else:
        return 'Night'


# Apply the transformation function to the Timestamp column and store the result in a new column
clicked_data['Slot'] = clicked_data['Timestamp'].apply(convert_timestamp_to_time_slot)

# Print the first few rows of the DataFrame to check the result
clicked_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create a dictionary to map categorical values to numerical labels
mapping = {'Morning': 0, 'Day': 1, 'Evening': 2, 'Night': 3}

# Create an instance of LabelEncoder with the mapping dictionary
le = LabelEncoder()
le.fit(clicked_data['Slot'].map(mapping))

# Transform the "Slot" column using the fitted encoder and the mapping dictionary
clicked_data['Time Slot'] = le.transform(clicked_data['Slot'].map(mapping))

# Print the first 5 rows of the transformed DataFrame to verify the results
print(clicked_data.head())
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad     Slot  Time Slot
# ...

# %%
clicked_data.drop('Ad Topic Line',axis =1, inplace=True)
clicked_data.drop('City',axis =1, inplace=True)
clicked_data.drop('Country',axis =1, inplace=True)
clicked_data.drop('Timestamp',axis =1, inplace=True)
clicked_data.drop('Slot',axis =1, inplace=True)

# %%
clicked_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#      Clicked on Ad  Time Slot
# ...

# %%
clicked_data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Male', 'Clicked on Ad', 'Time Slot'],
#       dtype='object')

# %%
feature =clicked_data[ ['Daily Time Spent on Site','Age', 'Area Income','Daily Internet Usage','Male','Time Slot']]

x = np.asarray(feature)
y = np.asarray(clicked_data['Clicked on Ad'])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.25,random_state=2)

# %%
from sklearn import svm


classifier_svm = svm.SVC(kernel='linear',gamma='auto',C=3)

# %%
classifier_svm.fit(x_train,y_train)
# Out:
# SVC(C=3, gamma='auto', kernel='linear')

# %%
predict_svm = classifier_svm.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predict_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       131
#            1       0.99      0.97      0.98       119
#
#     accuracy                           0.98       250
#    macro avg       0.98      0.98      0.98       250
# weighted avg       0.98      0.98      0.98       250

# %%
classifier_svm.score(x_test,y_test)
# Out:
# 0.984

# %%
import pickle
filename='Social_media_ads_classification.pkl'
pickle.dump(classifier_svm,open(filename,'wb'))
# loading the saved model
loaded_model=pickle.load(open('Social_media_ads_classification.pkl','rb'))
